# %%
# %%latex
# \[\]
# \[\]
# \[ P_{A} =\begin{bmatrix}
# 0.5 & 0.5 \\
# 0.5 & 0.5 \\
# \end{bmatrix}
# \]
# \[\]
# \[\]
# \[ P_{B} =\begin{bmatrix}
# 0.5 & 0.5 \\
# 0.5 & 0.5 \\
# \end{bmatrix}
# \]
# \[\]
# \[\]
# \[ P_{S} =\begin{bmatrix}
# 1 & 0 \\
# 0 & 1 \\
# \end{bmatrix}
# \]
# \[\]
# \[\]
# Out:
# \[\]
# \[\]
# \[ P_{A} =\begin{bmatrix}
# 0.5 & 0.5 \\
# 0.5 & 0.5 \\
# \end{bmatrix}
# \]
# \[\]
# \[\]
# \[ P_{B} =\begin{bmatrix}
# 0.5 & 0.5 \\
# 0.5 & 0.5 \\
# \end{bmatrix}
# \]
# \[\]
# \[\]
# \[ P_{S} =\begin{bmatrix}
# 1 & 0 \\
# 0 & 1 \\
# \end{bmatrix}
# \]
# \[\]
# \[\]

# %%
# %%latex
# \[\]
# \[\]
# \[
# \mathcal{X} = \{A, B\}
# \]
# \[\]
# \[\]
# \[
# \mathcal{A} = \{A, B, S\}
# \]
# \[\]
# \[\]
# \[
# \mathcal{Z} = \{A, B, \emptyset \}
# \]
# \[\]
# \[\]
# Out:
# \[\]
# \[\]
# \[
# \mathcal{X} = \{A, B\}
# \]
# \[\]
# \[\]
# \[
# \mathcal{A} = \{A, B, S\}
# \]
# \[\]
# \[\]
# \[
# \mathcal{Z} = \{A, B, \emptyset \}
# \]
# \[\]
# \[\]

# %%
# %%latex
# \[\]
# \[\]
# \[ O_{A} =\begin{bmatrix}
# 0 & 0 & 1  \\
# 0 & 0 & 1  \\
# \end{bmatrix}
# \]
# \[\]
# \[\]
# \[ O_{B} =\begin{bmatrix}
# 0 & 0 & 1  \\
# 0 & 0 & 1  \\
# \end{bmatrix}
# \]
# \[\]
# \[\]
# \[ O_{S} =\begin{bmatrix}
# 0.9 & 0.1 & 0  \\
# 0.1 & 0.9 & 0  \\
# \end{bmatrix}
# \]
# \[\]
# \[\]
# Out:
# \textchi = \{A, B\}
# \[\]
# \[\]
# \[ O_{A} =\begin{bmatrix}
# 0 & 0 & 1  \\
# 0 & 0 & 1  \\
# \end{bmatrix}
# \]
# \[\]
# \[\]
# \[ O_{B} =\begin{bmatrix}
# 0 & 0 & 1  \\
# 0 & 0 & 1  \\
# \end{bmatrix}
# \]
# \[\]
# \[\]
# \[ O_{S} =\begin{bmatrix}
# 0.9 & 0.1 & 0  \\
# 0.1 & 0.9 & 0  \\
# \end{bmatrix}
# \]
# \[\]
# \[\]

# %%
# %%latex
# \[\]
# \[\]
# \[ C = \begin{bmatrix}
# 0 & 1 & 0.5\\
# 1 & 0 & 0.5\\
# \end{bmatrix} \]
# \[\]
# \[\]
# Out:
# \[\]
# \[\]
# \[ C = \begin{bmatrix}
# 0 & 1 & 0.5\\
# 1 & 0 & 0.5\\
# \end{bmatrix} \]
# \[\]
# \[\]

# %%
# %%latex
# \[\]
# \[\]
# \[
# b_{new} = \xi \hspace{0.05cm} b_{old} \hspace{0.05cm} P_{S} \hspace{0.05cm} diag(O_{S})
# \]\[\]
# \[
# b_{new} = \xi
# \hspace{0.1cm}
# \begin{bmatrix}
# 0.7 & 0.3 \\
# \end{bmatrix}
# \hspace{0.1cm}
# \begin{bmatrix}
# 1 & 0\\
# 0 & 1\\
# \end{bmatrix}
# \hspace{0.1cm}
# \begin{bmatrix}
# 0.1 & 0\\
# 0 & 0.9\\
# \end{bmatrix}
# \]
# \[\]
# \[
# b_{new} =
# \begin{bmatrix}
# 0.2059 & 0.7941 \\
# \end{bmatrix}
# \]
# \[\]
# \[\]
# Out:
# \[\]
# \[\]
# \[
# b_{new} = \xi \hspace{0.05cm} b_{old} \hspace{0.05cm} P_{S} \hspace{0.05cm} diag(O_{S})
# \]\[\]
# \[
# b_{new} = \xi
# \hspace{0.1cm}
# \begin{bmatrix}
# 0.7 & 0.3 \\
# \end{bmatrix}
# \hspace{0.1cm}
# \begin{bmatrix}
# 1 & 0\\
# 0 & 1\\
# \end{bmatrix}
# \hspace{0.1cm}
# \begin{bmatrix}
# 0.1 & 0\\
# 0 & 0.9\\
# \end{bmatrix}
# \]
# \[\]
# \[
# b_{new} =
# \begin{bmatrix}
# 0.2059 & 0.7941 \\
# \end{bmatrix}
# \]
# \[\]
# \[\]
