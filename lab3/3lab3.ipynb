# %% [markdown]
# # Learning and Decision Making

# %% [markdown]
# ## Laboratory 3: Partially observable Markov decision problems
#
# In the end of the lab, you should submit all code/answers written in the tasks marked as "Activity n. XXX", together with the corresponding outputs and any replies to specific questions posed to the e-mail <adi.tecnico@gmail.com>. Make sure that the subject is of the form [&lt;group n.&gt;] LAB &lt;lab n.&gt;.

# %% [markdown]
# ### 1. Modeling
#
# Consider once again the princess saving problem described in the Homework and which you described as a POMDP.
#
# Recall that:
#
# * The princess can be in any one of two towers: Tower *A* and Tower *B*. The knight must decide which tower do invade to rescue the princess.
#
# * The knight can try to _peer_ at the towers, to figure out where the princess may be.
#
# * When the agent peers, it sees the princess in the right location with a probability of 0.9, and at the wrong location with probability 0.1.
#
# * Whenever the knight invades a tower, the "world" resets.
#
# Consider throughout that $\gamma=0.9$.

# %% [markdown]
# ---
#
# #### Activity 1.
#
# Implement your POMDP in Python. In particular,
#
# * Create a list with all the states;
# * Create a list with all the actions;
# * Create a list with all the observations
# * For each action, define a `numpy` array with the corresponding transition probabilities;
# * For each action, define a `numpy` array with the corresponding observation probabilities;
# * Define a `numpy` array with the cost describing the problem. Make sure that the costs lie in the interval [0,1] and that the cost for peering is in the middle between the cost for saving and being captured.
#
# The order for the states and actions used in the transition probability and cost matrices should match that in the lists of states and actions.
#
# **Note**: Don't forget to import `numpy`.
#
# ---

# %%
import numpy as np
np.set_printoptions(precision=3)
# states space
# 0 -> A 
# 1 -> B
states = [0,1]
print("\nStates: %s" % states)

# TODO PRINTS
# actions space
# 0 -> A
# 1 -> B
# 2 -> S
actions = [0,1,2]
print("\nActions: %s" % actions)

# observations space
# 0 -> A
# 1 -> B
# 2 -> None
observations = [0,1,2]
print("\nObservations: %s" % observations)

# Gamma
gamma = 0.9
print("\nGamma: %.2f" % gamma)

P=[[],[],[]]
P[0] = np.array([[0.5,0.5], [0.5,0.5]])
P[1] = np.array([[0.5,0.5], [0.5,0.5]])
P[2] = np.array([[1,0], [0,1]])

print("\nTransition Probability Matrix for each Action:")
for action, p_matrix in enumerate(P):
    actions_map =["A","B", "Scope"] # actions mapper for pretty print
    print("%s:\n%s\n" % (actions_map[action],p_matrix))

O =[[],[],[]]
O[0] = np.array([[0,0,1], [0,0,1]]) 
O[1] = np.array([[0,0,1], [0,0,1]]) 
O[2] = np.array([[0.9,0.1,0], [0.1,0.9,0]]) 
print("\nObservation Probability Matrix for each Action:")
for action, p_matrix in enumerate(O):
    actions_map =["A","B", "Scope"] # actions mapper for pretty print
    print("%s:\n%s\n" % (actions_map[action],p_matrix))

# Cost function
C = np.array([[0,1,0.5], [1,0,0.5]]) 
print("Cost function:\n%s" % C)
# Out:
# States: [0, 1]
#
# Actions: [0, 1, 2]
#
# Observations: [0, 1, 2]
#
# Gamma: 0.90
#
# Transition Probability Matrix for each Action:
# A:
# [[0.5 0.5]
#  [0.5 0.5]]
#
# B:
# [[0.5 0.5]
#  [0.5 0.5]]
#
# Scope:
# [[1 0]
#  [0 1]]
#
#
# Observation Probability Matrix for each Action:
# A:
# [[0 0 1]
#  [0 0 1]]
#
# B:
# [[0 0 1]
#  [0 0 1]]
#
# Scope:
# [[0.9 0.1 0. ]
#  [0.1 0.9 0. ]]
#
# Cost function:
# [[0.  1.  0.5]
#  [1.  0.  0.5]]

# %% [markdown]
# ### 2. Sampling
#
# You are now going to sample random trajectories of your POMDP and observe the impact it has on the corresponding belief.

# %% [markdown]
# ---
#
# #### Activity 2.
#
# Generate a random POMDP trajectory using a uniformly random policy. In particular, from a random initial state $x_0$ generate:
#
# 1. A sequence of 10,000 states by selecting the actions uniformly at random;
# 2. The corresponding sequence of 10,000 actions;
# 3. The corresponding sequence of 10,000 observations.
#
# ---

# %%
import random
pi = np.array([[1/3,1/3,1/3],[1/3,1/3,1/3]])

print("Policy:",pi)

act2_states, act2_actions, act2_observations = [], [], []
state = random.choice(states)
action = np.random.choice(actions, p=pi[state])

for i in range(10000):
    # Random action and next state , and next observation based in current action and next_state
    next_state = np.random.choice(states, p=P[action][state])
    next_action = np.random.choice(actions, p=pi[next_state])
    act2_observations.append(np.random.choice(observations, p=O[action][next_state]))
    act2_states.append(state)
    act2_actions.append(action)
    state, action = next_state, next_action
    
print("10k states:",np.array(act2_states))
print("10k actions",np.array(act2_actions))
print("10k observations",np.array(act2_observations))
# Out:
# Policy: [[0.333 0.333 0.333]
#  [0.333 0.333 0.333]]
# 10k states: [0 0 0 ... 0 1 1]
# 10k actions [2 1 0 ... 0 2 0]
# 10k observations [0 2 2 ... 2 1 2]

# %% [markdown]
# ---
#
# #### Activity 3.
#
# For the POMDP trajectory generated in Activity 2, compute the corresponding sequence of beliefs, assuming that the initial belief is $\mathbf{b}_0=[0.5, 0.5]$. Report the resulting beliefs, ignoring duplicate beliefs or beliefs whose distance is smaller than $10^{-3}$.
#
# **Note 1:** You may want to define a function `belief_update` that receives a belief, an action and an observation and returns the updated belief.
#
# **Note 2:** To compute the distance between vectors, you may find useful `numpy`'s function `linalg.norm`.
#
#
# ---

# %%
# intial_belief
belief = np.array([0.5, 0.5])
beliefs = [belief]

def belief_update(b, a, o):
    # Parameters: b -> belief | a -> action | o -> observation
    # Calculate new belief using belief update formul
    new_belief = (b.dot(P[a])).dot(np.diag(O[a][:,o]))
    return new_belief / sum(new_belief)

def validateBelief(next_belief, beliefs):
    # Parameters: next_belief -> belief to be validated | beliefs -> current set of beliefs
    # Validate belief according to requested conditions: "ignoring duplicate beliefs" (1) or "beliefs whose distance is smaller than 10−3" (2)
    return not (beliefs == next_belief).all(1).any() and not [b for b in beliefs if np.linalg.norm(b-next_belief) < 1e-3]
                        
for i in range(10000):
    # next_belief based on      
    next_belief = belief_update(belief,act2_actions[i],act2_observations[i])
    if validateBelief(next_belief,beliefs):
        beliefs.append(next_belief)
    belief = next_belief

print("Beliefs:\n%s" % np.array(beliefs))
# Out:
# Beliefs:
# [[5.000e-01 5.000e-01]
#  [9.000e-01 1.000e-01]
#  [9.878e-01 1.220e-02]
#  [1.000e-01 9.000e-01]
#  [1.220e-02 9.878e-01]
#  [9.986e-01 1.370e-03]
#  [1.370e-03 9.986e-01]
#  [1.524e-04 9.998e-01]
#  [9.998e-01 1.524e-04]]

# %% [markdown]
# ### 3. Solution methods
#
# In this section you are going to compare different non-exact solution methods.

# %% [markdown]
# ---
#
# #### Activity 4
#
# Compute the solution for the underlying MDP and report the corresponding optimal policy and optimal cost-to-go.
#
# ** Note:** You may reuse code from previous labs.
#
# ---

# %%
import time
# Initial policy is 0.33 in every cell of the matrix, defined in activity2
pi = np.array([[1/3,1/3,1/3],[1/3,1/3,1/3]])
# Initialize policy iteration variables and starttime
quit = False
Q=[[],[],[]]
t0 = time.time()

# Policy iteration loop
while not quit:
    # Cost associated with the current (looped) policy     
    C_pi = np.diag(pi[:,0]).dot(C[:,0,None]) + np.diag(pi[:,1]).dot(C[:,1,None]) + np.diag(pi[:,2]).dot(C[:,2,None])
    
    # Probability Matrix associated with the current (looped) policy
    P_pi = np.diag(pi[:,0]).dot(P[0]) + np.diag(pi[:,1]).dot(P[1]) + np.diag(pi[:,2]).dot(P[2])
    
    # Cost-to-go associated with the current (looped) policy
    J = np.dot(np.linalg.inv(np.identity(2) - gamma* P_pi), C_pi)

    # Get Q-functions for each action
    for j in range(3):
        Q[j] = C[:,j,None] + gamma * P[j].dot(J)

    # Calculate new policy
    Pi_new = np.zeros((2,3))
    for j in range(3):
        Pi_new[:,j,None] = np.isclose(Q[j], np.min([Q[0],Q[1],Q[2]], axis=0), atol=1e-8, rtol=1e-8).astype(int)
 
    # Normalize calculated policy
    Pi_new = Pi_new / np.sum(Pi_new, axis=1, keepdims = True)
    
    # Update policy iteration loop variables
    quit = (pi == Pi_new).all()
    pi = Pi_new   
    i += 1
    
print("Time to compute: %.6f seconds" % (time.time() - t0))
print("Optimal cost-to-go:\n%s" % J)
print("The optimal policy:\n%s" % pi)
# Out:
# Time to compute: 0.091298 seconds
# Optimal cost-to-go:
# [[0.]
#  [0.]]
# The optimal policy:
# [[1. 0. 0.]
#  [0. 1. 0.]]

# %% [markdown]
# ---
#
# #### Activity 5
#
# For each of the beliefs computed in Activity 3, compute the action prescribed by:
#
# * The MLS heuristic;
# * The AV heuristic;
# * The Q-MDP heuristic.
#
# ---

# %%
mls = []
av = []
q_mdp = []
# from activity 4
Q_mdp = np.concatenate((Q[0],Q[1],Q[2]),axis=1)
print("Q_pi:\n",Q_mdp)
for b in beliefs:
    # MLS heuristic according to formula
    mls.append([b, actions_map[np.argmax(pi[np.argmax(b)])]])
    # AV heuristic according to formula
    av.append([b, actions_map[np.argmax(np.dot(b,pi))]])
    # Q-MDP heuristic according to formula
    q_mdp.append([b, actions_map[np.argmin(np.dot(b,Q_mdp))]])
    
print("MLS heuristic (action prescribed per belief):\n%s\n" % np.array(mls))
print("AV heuristic (action prescribed per belief):\n%s\n" % np.array(av))
print("Q-MDP heuristic (action prescribed per belief):\n%s\n" % np.array(q_mdp))
# Out:
# Q_pi:
#  [[0.  1.  0.5]
#  [1.  0.  0.5]]
# MLS heuristic (action prescribed per belief):
# [[array([0.5, 0.5]) 'A']
#  [array([0.9, 0.1]) 'A']
#  [array([0.988, 0.012]) 'A']
#  [array([0.1, 0.9]) 'B']
#  [array([0.012, 0.988]) 'B']
#  [array([0.999, 0.001]) 'A']
#  [array([0.001, 0.999]) 'B']
#  [array([1.524e-04, 9.998e-01]) 'B']
#  [array([9.998e-01, 1.524e-04]) 'A']]
#
# AV heuristic (action prescribed per belief):
# [[array([0.5, 0.5]) 'A']
#  [array([0.9, 0.1]) 'A']
#  [array([0.988, 0.012]) 'A']
#  [array([0.1, 0.9]) 'B']
#  [array([0.012, 0.988]) 'B']
#  [array([0.999, 0.001]) 'A']
#  [array([0.001, 0.999]) 'B']
#  [array([1.524e-04, 9.998e-01]) 'B']
#  [array([9.998e-01, 1.524e-04]) 'A']]
#
# Q-MDP heuristic (action prescribed per belief):
# [[array([0.5, 0.5]) 'A']
#  [array([0.9, 0.1]) 'A']
#  [array([0.988, 0.012]) 'A']
#  [array([0.1, 0.9]) 'B']
#  [array([0.012, 0.988]) 'B']
#  [array([0.999, 0.001]) 'A']
#  [array([0.001, 0.999]) 'B']
#  [array([1.524e-04, 9.998e-01]) 'B']
#  [array([9.998e-01, 1.524e-04]) 'A']]

# %% [markdown]
# ---
#
# #### Activity 6
#
# Suppose that the optimal cost-to-go function for the POMDP can be represented using the $\alpha$-vectors
#
# $$
# \left\{
# \begin{bmatrix}
# 2.795\\
# 3.795
# \end{bmatrix},
# \begin{bmatrix}
# 3.795\\
# 2.795
# \end{bmatrix},
# \begin{bmatrix}
# 3.105\\
# 3.105
# \end{bmatrix}\right\}$$
#
# corresponding to the actions 'Invade Tower A', 'Invade Tower B' and 'Peer', respectively. Represent the optimal cost-to-go function and compare the optimal policy with the MDP heuristics from Activity 5 in the beliefs computed in Activity 3.
#
# ** Note: ** Don't forget to import `matplotlib`, and use the magic `%matplotlib notebook`.
#
# ---

# %%
# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt
import math

# maps for actions and colors
act5_actions =["Invade\n Tower A","Invade\n Tower B", "Peer"]

# alpha_vectors = [[2.795,3.795],[3.795,2.795],[3.105,3.105]]
alpha_vectors = np.array([np.array([[2.795],[3.795]]),np.array([[3.795],[2.795]]),np.array([[3.105],[3.105]])])

# alpha vectors concatenated
pomdp = np.concatenate((alpha_vectors[0],alpha_vectors[1], alpha_vectors[2]),axis=1)


def drawAlphaVectors():
    plt.title("Value Interation J")
    plt.xlabel("p=P[x=B]")
    plt.ylabel("J_pi")
    plt.plot(alpha_vectors[0],"blue", label=act5_actions[0])
    plt.plot(alpha_vectors[1],"orange", label=act5_actions[1])
    plt.plot(alpha_vectors[2],"red", label=act5_actions[2])
    plt.tight_layout(rect=[0,0,0.75,1])
    plt.legend(bbox_to_anchor=(1.04,1), loc="upper left", labelspacing=2)
    plt.show()

# return the argmin from the dot between the belief and the alpha vectors
def chooseAction(belief,vecs):
    return act5_actions[np.argmin(np.dot(b,vecs))]

# draw heuristics' results
def drawPoint(b, heur,color,size, heur_name):
    plt.scatter(b[1],act5_actions[actions_map.index(heur[i][1])],c=color, s=size, label=heur_name)

# draw optimal policy points
def drawPointPOMDP(b, color,size):
    action = chooseAction(b,alpha_vectors)
    plt.scatter(b[1],action,c=color, s=size, label="Optimal\n Policy")

# generate graph
drawAlphaVectors()

plt.figure()
plt.xlabel("p=P[x=B]")
plt.ylabel("Actions")
plt.title("Heuristics VS Optimal Policy")
plt.tight_layout(rect=[0,0,0.75,1])

# print results
print("Alpha Vectors:\n", alpha_vectors)
# from len(beliefs)-1 to 0, so "Peer" is the last one to appear
for i in range(len(beliefs)-1,-1,-1):
    b = beliefs[i]
    # draw points 
    drawPoint(b, mls, "blue",700,"MLS")
    drawPoint(b, av, "yellow",400,"AV")
    drawPoint(b, q_mdp, "red",200,"Q-MDP")
    drawPointPOMDP(b, "green",50)
    # print heuristics' results
    if i == len(beliefs)-1:
        plt.legend(bbox_to_anchor=(1.04,1), loc="upper left", labelspacing=5)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Alpha Vectors:
#  [[[2.795]
#   [3.795]]
#
#  [[3.795]
#   [2.795]]
#
#  [[3.105]
#   [3.105]]]

# %% [markdown]
# A optimal policy é é a àrea debaixo da intersecção dos vários alphas, ou seja, até mais ou menos 0.3 é a ação "Invade Tower A", de 0.3 a 0.7 é a ação "Peer" e 0.7 a 1 é a acção "Invade Tower B".
# Como podemos verificar pelo gráfico "Heuristics VS Optimal Policy", o único belief cuja ação, calculada pelas heuristicas do MDP, não coincide é o belief [0.5,0.5].
